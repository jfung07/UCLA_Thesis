# %% [markdown]
# # 1. Setup

# %%
# packages
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets
import torchvision.transforms as transforms

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
import random
import shutil
from PIL import Image

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Running on device {device}")

torch.manual_seed(256)
np.random.seed(256)
# Out:
# Running on device cuda:0

# %% [markdown]
# # **All directories are based on google colab's file structure.**

# %% [markdown]
# # 2. Data

# %% [markdown]
# Clone Repo

# %%
# !git clone https://github.com/jfung07/UCLA_Thesis
# Out:
# Cloning into 'UCLA_Thesis'...
# remote: Enumerating objects: 1719, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 1719 (delta 0), reused 7 (delta 0), pack-reused 1711 (from 1)
# Receiving objects: 100% (1719/1719), 928.00 MiB | 32.80 MiB/s, done.
# Updating files: 100% (1683/1683), done.

# %% [markdown]
# ## 2a. CSV

# %%
base = "/content/UCLA_Thesis/data"
df = pd.read_excel("UCLA_Thesis/data/setters.xlsx")

# %% [markdown]
# ### 2a1. Response Variable

# %% [markdown]
# Set Receiver

# %%
nums = df['set_receiver'].value_counts()
fig, ax = plt.subplots(figsize = (15,4))
ax.bar(nums.index.astype(str), nums.values)
ax.set_xlabel("Set Receiver")
ax.set_ylabel("Frequency")
ax.set_title("Set Receiver Distribution")
plt.show()

# %% [markdown]
# ### 2a2. Clean Receivers

# %%
rec_data_path = os.path.join(base, "rec_data")
os.makedirs(os.path.join(rec_data_path))
src = os.path.join(base, "setters.xlsx")
dst = os.path.join(rec_data_path, "setters.xlsx")
os.makedirs(os.path.dirname(dst), exist_ok = True)
shutil.copy(src, dst)
rec_df = pd.read_excel(os.path.join(rec_data_path, "setters.xlsx"))
rec_df.loc[
    rec_df["set_receiver"].isin(["ds", "libero", "setter1", "setter2", "opposite2", "outside3", "middle1", "middle2", "middle3"]),
    "set_receiver"
] = "nonpin"

# %%
nums = rec_df['set_receiver'].value_counts()
fig, ax = plt.subplots(figsize = (15,4))
ax.bar(nums.index.astype(str), nums.values)
ax.set_xlabel("Set Receiver")
ax.set_ylabel("Frequency")
ax.set_title("Set Receiver Distribution")
plt.show()

# %% [markdown]
# ## 2b. Images

# %% [markdown]
# ###2b1. Label Images

# %%
base = "/content/UCLA_Thesis/data"
labeled_path = os.path.join(base, "rec_data", "labeled_set_images") # /content/UCLA_Thesis/data/rec_data/labeled_set_images
os.makedirs(labeled_path, exist_ok=True)
num_images = 0
for game_set in os.listdir(os.path.join(base, "set_images")):
  game_set_path = os.path.join(base, "set_images", game_set) # EX: /content/UCLA_Thesis/data/game_set/game2_set1
  for pos_image in os.listdir(game_set_path): # loops through images within a gameset
    if not pos_image.lower().endswith(".png"):
      continue
    csv_index = int(pos_image.replace("set", "").replace(".png", "").strip()) - 1
    label = str(rec_df['set_receiver'][csv_index])
    class_folder = os.path.join(labeled_path, game_set, label)
    os.makedirs(class_folder, exist_ok=True)
    shutil.copy(os.path.join(game_set_path, pos_image), os.path.join(labeled_path, game_set, class_folder, pos_image)) # from original to labeled path
    num_images += 1

print(f"labeled {num_images} images")
# Out:
# labeled 1677 images

# %% [markdown]
# ###2b2. Split

# %%
# folders
splits = ["train", "val", "test"]
split_images_path = os.path.join(base, "rec_data", "setRec_split") # /content/UCLA_Thesis/data/rec_data/setRec_split
os.makedirs(split_images_path, exist_ok=True)
for game_set in os.listdir(labeled_path): # labeled path = /content/UCLA_Thesis/data/labeled_set_images
  game_set_splits_path = os.path.join(split_images_path, game_set) # EX. /content/UCLA_Thesis/data/rec_loc/setRec_split/game2_set1
  for s in splits:
    os.makedirs(os.path.join(game_set_splits_path, s), exist_ok=True)

# %%
# populate
np.random.seed(256)
for game_set in os.listdir(labeled_path): # labeled path = /content/UCLA_Thesis/data/rec_data/labeled_set_images
  game_set_path = os.path.join(labeled_path, game_set) # EX. /content/UCLA_Thesis/data/rec_data/labeled_set_images/game2_set1
  for rec in os.listdir(game_set_path):
    rec_path = os.path.join(game_set_path, rec) # EX. /content/UCLA_Thesis/data/labeled_set_images/game2_set1/outside1
    imgs = [f for f in os.listdir(rec_path) if f.lower().endswith(".png")]
    random.shuffle(imgs)
    n = len(imgs)
    train_end = int(0.7 * n)
    val_end = int(0.85 * n)
    train_imgs, val_imgs, test_imgs = imgs[:train_end], imgs[train_end:val_end], imgs[val_end:]
    # loc within split
    for s in splits:
      # make folders
      os.makedirs(os.path.join(split_images_path, game_set, s, rec), exist_ok = True)
    for subset, subset_imgs in zip(splits, [train_imgs, val_imgs, test_imgs]):
      outdir = os.path.join(split_images_path, game_set, subset, rec)

      for file in subset_imgs:
        shutil.copy(os.path.join(rec_path, file), os.path.join(outdir, file))

# %% [markdown]
# #### CSV lines based on split

# %% [markdown]
# Train

# %%
rec_train_df = pd.DataFrame()
# loop through game sets in split
split_images_path = os.path.join(base, "rec_data", "setRec_split")
for game_set in os.listdir(split_images_path):
  # go through train of each game
  train_path = os.path.join(split_images_path, game_set, "train")
  # loop through receivers
  for rec in os.listdir(train_path):
    rec_path = os.path.join(train_path, rec)
    for pos_image in os.listdir(rec_path):
      csv_index = int(pos_image.replace("set", "").replace(".png", "").strip()) - 1
      row = df.loc[csv_index]
      rec_train_df = pd.concat([rec_train_df, row.to_frame().T], ignore_index=True)
out_path = "/content/UCLA_Thesis/data/rec_data/train.xlsx"
os.makedirs(os.path.dirname(out_path), exist_ok = True)
rec_train_df.to_excel(out_path, index = False)

# %%
print(len(rec_train_df))
rec_train_df.head(5)
# Out:
# 1131
#   observation points1 points2 team1_diff team2_diff tot_point set game  \
# 0        1862       6       4          2         -2        10   3    8
# 1        1865       6       5          1         -1        11   3    8
# 2        1873      10       9          1         -1        19   3    8
# 3        1878      15      10          5         -5        25   3    8
# 4        1867       7       6          1         -1        13   3    8
#
#   rotation receiver_loc pass_loc pass_quality set_loc num_block set_receiver  \
# 0        3            5        3            4       5         2    opposite1
# 1        6            5        3            4       D         2    opposite1
# 2        3            5        3            4       5         1    opposite1
# 3        2            1        3            4       5         2    opposite1
# 4        5            7        7            5       D         2    opposite1
#
#   kill    team level game_sex
# 0    1  japanM   Pro        M
# 1    1  france   Pro        M
# 2    1  france   Pro        M
# 3    1  japanM   Pro        M
# 4    1  japanM   Pro        M

# %% [markdown]
# Validation

# %%
rec_val_df = pd.DataFrame()
# loop through game sets in split
split_images_path = os.path.join(base, "rec_data", "setRec_split")
for game_set in os.listdir(split_images_path):
  # go through val of each game
  val_path = os.path.join(split_images_path, game_set, "val")
  # loop through receivers
  for rec in os.listdir(val_path):
    rec_path = os.path.join(val_path, rec)
    for pos_image in os.listdir(rec_path):
      csv_index = int(pos_image.replace("set", "").replace(".png", "").strip()) - 1
      row = df.loc[csv_index]
      rec_val_df = pd.concat([rec_val_df, row.to_frame().T], ignore_index=True)

out_path = "/content/UCLA_Thesis/data/rec_data/val.xlsx"
os.makedirs(os.path.dirname(out_path), exist_ok = True)
rec_val_df.to_excel(out_path, index = False)

# %%
print(len(rec_val_df))
rec_val_df.head(5)
# Out:
# 250
#   observation points1 points2 team1_diff team2_diff tot_point set game  \
# 0        1897      21      16          5         -5        37   3    8
# 1        1871       9       8          1         -1        17   3    8
# 2        1893      20      15          5         -5        35   3    8
# 3        1861       5       4          1         -1         9   3    8
# 4        1892      20      15          5         -5        35   3    8
#
#   rotation receiver_loc pass_loc pass_quality set_loc num_block set_receiver  \
# 0        4            5        3            4       D         2    opposite1
# 1        6            5        4            2       D         3    opposite1
# 2        1            6        7            5       4         1     outside2
# 3        5            1        7            5       4         1     outside1
# 4        4            7        7            5       1         2      middle2
#
#   kill    team level game_sex
# 0    0  france   Pro        M
# 1    0  japanM   Pro        M
# 2    0  japanM   Pro        M
# 3    1  france   Pro        M
# 4    0  france   Pro        M

# %% [markdown]
# Test

# %%
rec_test_df = pd.DataFrame()
# loop through game sets in split
split_images_path = os.path.join(base, "rec_data", "setRec_split")
for game_set in os.listdir(split_images_path):
  # go through test of each game
  test_path = os.path.join(split_images_path, game_set, "test")
  # loop through receivers
  for rec in os.listdir(test_path):
    rec_path = os.path.join(test_path, rec)
    for pos_image in os.listdir(rec_path):
      csv_index = int(pos_image.replace("set", "").replace(".png", "").strip()) - 1
      row = df.loc[csv_index]
      rec_test_df = pd.concat([rec_test_df, row.to_frame().T], ignore_index=True)

out_path = "/content/UCLA_Thesis/data/rec_data/test.xlsx"
os.makedirs(os.path.dirname(out_path), exist_ok = True)
rec_test_df.to_excel(out_path, index = False)

# %%
print(len(rec_test_df))
rec_test_df.head(5)
# Out:
# 296
#   observation points1 points2 team1_diff team2_diff tot_point set game  \
# 0        1898      21      17          4         -4        38   3    8
# 1        1891      19      15          4         -4        34   3    8
# 2        1886      19      14          5         -5        33   3    8
# 3        1856       2       1          1         -1         3   3    8
# 4        1858       3       1          2         -2         4   3    8
#
#   rotation receiver_loc pass_loc pass_quality set_loc num_block set_receiver  \
# 0        4            5        7            5       D         1    opposite1
# 1        3            3        3            4       5         2    opposite1
# 2        3            6        2            3       4         2     outside2
# 3        6            5        4            3       4         2     outside1
# 4        6            4        7            5       4         2     outside1
#
#   kill    team level game_sex
# 0    1  france   Pro        M
# 1    1  france   Pro        M
# 2    0  france   Pro        M
# 3    0  japanM   Pro        M
# 4    0  japanM   Pro        M

# %% [markdown]
# Delete labeled_setRec_images

# %%
shutil.rmtree(labeled_path)

# %% [markdown]
# ### 2b3. Combined Split

# %% [markdown]
# Train

# %%
split_comb_path = os.path.join(base, "rec_data", "split_comb") # /content/UCLA_Thesis/data/rec_data/split_comb
os.makedirs(os.path.dirname(split_comb_path), exist_ok=True)
train_comb_path = os.path.join(split_comb_path, "train_comb") # /content/UCLA_Thesis/data/rec_data/split_comb/train_comb
os.makedirs(os.path.dirname(train_comb_path), exist_ok=True)
# loop through game sets
for game_set in os.listdir(split_images_path):
  # collect all train images across game sets
  game_set_train = os.path.join(base, "rec_data", "setRec_split", game_set, "train") # /content/UCLA_Thesis/data/rec_data/setRec_split/game2_set1/train
  for rec in os.listdir(game_set_train):
    rec_comb_path = os.path.join(train_comb_path, rec)
    os.makedirs(rec_comb_path, exist_ok=True)
    rec_path = os.path.join(game_set_train, rec)
    for pos_img in os.listdir(rec_path):
      src = os.path.join(rec_path, pos_img)
      dst = os.path.join(rec_comb_path, pos_img)
      os.makedirs(os.path.dirname(dst), exist_ok=True)
      shutil.copy(src, dst)

# %% [markdown]
# Validation

# %%
val_comb_path = os.path.join(split_comb_path, "val_comb") # /content/UCLA_Thesis/data/rec_data/split_comb/val_comb
os.makedirs(os.path.dirname(val_comb_path), exist_ok=True)
# loop through game sets
for game_set in os.listdir(split_images_path):
  # collect all validation images across game sets
  game_set_val = os.path.join(base, "rec_data", "setRec_split", game_set, "val") # /content/UCLA_Thesis/data/rec_data/setRec_split/game2_set1/val
  for rec in os.listdir(game_set_val):
    rec_comb_path = os.path.join(val_comb_path, rec)
    os.makedirs(rec_comb_path, exist_ok=True)
    rec_path = os.path.join(game_set_val, rec)
    for pos_img in os.listdir(rec_path):
      src = os.path.join(rec_path, pos_img)
      dst = os.path.join(rec_comb_path, pos_img)
      os.makedirs(os.path.dirname(dst), exist_ok=True)
      shutil.copy(src, dst)

# %% [markdown]
# Test

# %%
test_comb_path = os.path.join(split_comb_path, "test_comb") # /content/UCLA_Thesis/data/rec_data/split_comb/test_comb
os.makedirs(os.path.dirname(test_comb_path), exist_ok=True)
# loop through game sets
for game_set in os.listdir(split_images_path):
  # collect all testing images across game sets
  game_set_test = os.path.join(base, "rec_data", "setRec_split", game_set, "test") # /content/UCLA_Thesis/data/rec_data/setRec_split/game2_set1/test
  for rec in os.listdir(game_set_test):
    rec_comb_path = os.path.join(test_comb_path, rec)
    os.makedirs(rec_comb_path, exist_ok=True)
    rec_path = os.path.join(game_set_test, rec)
    for pos_img in os.listdir(rec_path):
      src = os.path.join(rec_path, pos_img)
      dst = os.path.join(rec_comb_path, pos_img)
      os.makedirs(os.path.dirname(dst), exist_ok=True)
      shutil.copy(src, dst)

# %% [markdown]
# ### 2b3. Transform Images

# %% [markdown]
# Get data mean and standard deviation for normalizing.  For this project, I am not analyzing within game, so I use the combination of all game set training sets, and same for the validation and test sets.  However, I split the data such that other research can analyze data within games.

# %%
means = []
stdevs = []
for rec in os.listdir(train_comb_path):
  for pos in os.listdir(os.path.join(train_comb_path, rec)):
    if not pos.lower().endswith((".png")):
      continue
    path = os.path.join(train_comb_path, rec, pos)
    img = Image.open(path).convert("RGB")
    arr = np.array(img) / 255.0
    means.append(arr.mean(axis = (0,1)))
    stdevs.append(arr.std(axis = (0,1)))
train_mean = np.mean(means, axis = 0)
train_stdev = np.mean(stdevs, axis = 0)
print(f"Mean: {train_mean} and Stdev: {train_stdev}")
# Out:
# Mean: [0.42265585 0.3999551  0.41333437] and Stdev: [0.3408886  0.27900828 0.25607526]

# %% [markdown]
# Transforms

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p = 0.5), # keeps ground and ceiling orientation
    # random cropping
    transforms.RandomResizedCrop(
      size = (1024, 512),
      scale = (0.8, 1.0),
      ratio = (1.8, 2.2)
    ),
    # random color
    transforms.ColorJitter(
        brightness = 0.2,
        contrast = 0.2,
        saturation = 0.2,
        hue = 0.05
    ),
    transforms.ToTensor(),
    transforms.Normalize(mean = train_mean, std = train_stdev)
])

val_test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean = train_mean, std = train_stdev)
])

# %% [markdown]
# Transform Data

# %%
train_ds = datasets.ImageFolder(train_comb_path,
                                transform = train_transform)
val_ds = datasets.ImageFolder(val_comb_path,
                              transform = val_test_transform)
test_ds = datasets.ImageFolder(test_comb_path,
                               transform = val_test_transform)
print(f"Training samples: {len(train_ds)}")
print(f"Validation samples: {len(val_ds)}")
print(f"Test samples: {len(test_ds)}")
# Out:
# Training samples: 1131
# Validation samples: 250
# Test samples: 296

# %% [markdown]
# ### 2b4. Data Loader

# %% [markdown]
# Use batch sizes of either 8 or 16 because images are large on a medium size data set.  8 generalizes better, but 16 is slightly faster.
# Choices:
# - 8
#   - lr = 0.0001 with adam or
#   - lr = 0.01, momentum = 0.9 with sgd
#   - scaler = torch.cuda.amp.GradScaler()
#   - num_workers = 2(colab)
# - 16
#   - lr = 0.0002 with adam or
#   - lr = 0.02, momentum = 0.9 with sgd
#   - scaler = torch.cuda.amp.GradScaler()
#   - num_workers = 4(colab)
#
# Use batch_size = 8 because VGG prefers it and works well with the simple model as well.

# %%
train_loader8 = DataLoader(train_ds, batch_size = 8, shuffle = True,
                           num_workers = 2, pin_memory = True,
                           persistent_workers=True)
val_loader8 = DataLoader(val_ds, batch_size = 8, shuffle = False,
                           num_workers = 2, pin_memory = True,
                           persistent_workers=True)
test_loader8 = DataLoader(test_ds, batch_size = 8, shuffle = False,
                           num_workers = 2, pin_memory = True,
                           persistent_workers=True)
print("For batch_size = 8:")
print(f"Number of training batches: {len(train_loader8)}")
print(f"Number of validation batches: {len(val_loader8)}")
print(f"Number of test batches: {len(test_loader8)}")
# Out:
# For batch_size = 8:
# Number of training batches: 142
# Number of validation batches: 32
# Number of test batches: 37

# %% [markdown]
# Structure

# %%
images, labels = next(iter(train_loader8))

print(f"Batch shape: {images.shape}")   # [batch_size, channels, height, width]
print(f"Labels shape: {labels.shape}")  # [batch_size]
print(f"Image dtype: {images.dtype}")
print(f"Label dtype: {labels.dtype}")
# Out:
# Batch shape: torch.Size([8, 3, 1024, 512])
# Labels shape: torch.Size([8])
# Image dtype: torch.float32
# Label dtype: torch.int64

# %% [markdown]
# # 3. Model

# %% [markdown]
# ##3a. Simple Baseline

# %%
class SimpleCNN(nn.Module):
  def __init__(self, num_classes = 6):
    super(SimpleCNN, self).__init__()
    # input is 1024x512x3 image

    # Block 1: 1024x512 -> 512x256
    self.block1 = nn.Sequential(
        nn.Conv2d(3, 32, kernel_size=3, stride = 1, padding = 1), # (32 filters, 3x3(kernel), padding = 1)
        nn.ReLU(inplace = True), #-> ReLU
        nn.MaxPool2d(kernel_size=2), # -> max pool 2x2
    )

    # Block 2: 512x256 -> 256x128
    self.block2 = nn.Sequential(
        nn.Conv2d(32, 64, kernel_size=3, stride = 1, padding = 1),
        nn.ReLU(inplace = True),
        nn.MaxPool2d(kernel_size = 2),
    )

    # Block 3: 256x128 -> 128x64
    self.block3 = nn.Sequential(
        nn.Conv2d(64, 64, kernel_size=3, stride = 1, padding = 1),
        nn.ReLU(inplace = True),
        nn.MaxPool2d(kernel_size=2),
    )

    # Block 4: 128x64 -> 64x32
    self.block4 = nn.Sequential(
        nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True),
        nn.MaxPool2d(kernel_size=2),
    )

    # Flatten Layer 64x32x64 -> 64*32*64
    self.flatten = nn.Flatten()

    # Fully Connected Later: 64*32*64 -> 64
    self.layer1 = nn.Linear(64 * 32 * 64, 64)
    self.activation = nn.ReLU()

    # Output Layer: 64 -> 7
    self.classifier = nn.Linear(64, num_classes)

  def forward(self, x):
    x = self.block1(x)
    x = self.block2(x)
    x = self.block3(x)
    x = self.block4(x)
    x = self.flatten(x)
    x = self.activation(self.layer1(x))
    x = self.classifier(x)
    return x

# %% [markdown]
# ### Summary

# %%
simple_model = SimpleCNN(num_classes=7).to(device)

# Print model architecture
print(simple_model)
print(f"\nTotal parameters: {sum(p.numel() for p in simple_model.parameters()):,}")
print(f"Trainable parameters: {sum(p.numel() for p in simple_model.parameters() if p.requires_grad):,}")
# Out:
# SimpleCNN(
#   (block1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block4): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (layer1): Linear(in_features=131072, out_features=64, bias=True)
#   (activation): ReLU()
#   (classifier): Linear(in_features=64, out_features=7, bias=True)
# )
#
# Total parameters: 8,482,375
# Trainable parameters: 8,482,375

# %% [markdown]
# ## 3b. VGG

# %%
from torch.nn.modules.batchnorm import BatchNorm2d

class VGG(nn.Module):
  def __init__(self, num_classes = 7):
    super().__init__()

    # Block 1: 1024x512 -> 512x256
    self.block1 = nn.Sequential(
      nn.Conv2d(3, 32, kernel_size=3, padding=1),
      BatchNorm2d(32),
      nn.ReLU(inplace = True),
      nn.MaxPool2d(2, 2),
    )

    # Block 2: 512x256 -> 256x128
    self.block2 = nn.Sequential(
      nn.Conv2d(32, 64, kernel_size=3, padding=1),
      BatchNorm2d(64),
      nn.ReLU(inplace = True),
      nn.MaxPool2d(2, 2),
    )

    # Block 3: 256x128 -> 128x64
    self.block3 = nn.Sequential(
      nn.Conv2d(64, 128, kernel_size=3, padding=1),
      BatchNorm2d(128),
      nn.ReLU(inplace = True),
      nn.Conv2d(128, 128, kernel_size=3, padding=1),
      BatchNorm2d(128),
      nn.ReLU(inplace = True),
      nn.MaxPool2d(2, 2),
    )

    # Block 4: 128x64 -> 64x32
    self.block4 = nn.Sequential(
      nn.Conv2d(128, 256, kernel_size=3, padding=1),
      BatchNorm2d(256),
      nn.ReLU(inplace = True),
      nn.Conv2d(256, 256, kernel_size=3, padding=1),
      BatchNorm2d(256),
      nn.ReLU(inplace = True),
      nn.MaxPool2d(2, 2),
    )

    # Block 5: 64x32 -> 32x16
    self.block5 = nn.Sequential(
      nn.Conv2d(256, 512, kernel_size=3, padding=1),
      BatchNorm2d(512),
      nn.ReLU(inplace = True),
      nn.Conv2d(512, 512, kernel_size=3, padding=1),
      BatchNorm2d(512),
      nn.ReLU(inplace = True),
      nn.MaxPool2d(2, 2),
    )

    self.gap = nn.AdaptiveAvgPool2d((1,1))
    self.classifier = nn.Linear(512, num_classes)

  def forward(self, x):
    x = self.block1(x)
    x = self.block2(x)
    x = self.block3(x)
    x = self.block4(x)
    x = self.block5(x)
    x = self.gap(x)
    x = x.view(x.size(0), -1)
    x = self.classifier(x)
    return x

# %% [markdown]
# ### Summary

# %%
vgg_model = VGG(num_classes=7).to(device)

# Print model architecture
print(vgg_model)
print(f"\nTotal parameters: {sum(p.numel() for p in vgg_model.parameters()):,}")
print(f"Trainable parameters: {sum(p.numel() for p in vgg_model.parameters() if p.requires_grad):,}")
# Out:
# VGG(
#   (block1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block5): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (gap): AdaptiveAvgPool2d(output_size=(1, 1))
#   (classifier): Linear(in_features=512, out_features=7, bias=True)
# )
#
# Total parameters: 4,673,415
# Trainable parameters: 4,673,415

# %% [markdown]
# # 4. Training and Evaluation Helpers

# %% [markdown]
# ##4a. Training Helper

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, device, scaler):
    """Train for one epoch"""
    model.train()
    running_loss = 0.0
    running_correct = 0
    total = 0

    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        # Zero gradients
        optimizer.zero_grad(set_to_none=True)

        # Forward pass
        with torch.cuda.amp.autocast():
          outputs = model(images)
          loss = criterion(outputs, labels)

        # Backward pass
        scaler.scale(loss).backward()

        # Update weights
        scaler.step(optimizer)
        scaler.update()

        # Statistics
        running_loss += loss.item() * images.size(0)
        _, preds = torch.max(outputs, 1)
        running_correct += (preds == labels).sum().item()
        total += labels.size(0)

    epoch_loss = running_loss / total
    epoch_acc = 100.0 * running_correct / total
    return epoch_loss, epoch_acc

# %% [markdown]
# ## 4b. Evaluation Helpers

# %%
def evaluate(model, val_loader, criterion, device):
    """Evaluate the model on test set"""
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    epoch_loss = running_loss / total
    epoch_acc = 100. * correct / total
    return epoch_loss, epoch_acc

# %%
from sklearn.metrics._plot.confusion_matrix import confusion_matrix
def plot_confusion_matrix(model, test_loader, devce, classes):
  model.eval()
  y_pred = []
  y_true = []

  with torch.no_grad():
    for images, labels in test_loader:
      images, labels = images.to(device), labels.to(device)
      outputs = model(images)
      _, predicted = outputs.max(1)

      y_pred.extend(predicted.cpu().numpy())
      y_true.extend(labels.cpu().numpy())

  cm = confusion_matrix(y_true, y_pred)
  return cm

# %% [markdown]
# # 5. Run Basic CNN

# %% [markdown]
# Configuration

# %%
# Training configuration
NUM_EPOCHS = 20
LEARNING_RATE = 0.0001

# Loss function
criterion = nn.CrossEntropyLoss()

# Optimizer
optimizer = optim.Adam(simple_model.parameters(), lr=LEARNING_RATE)

# Learning rate scheduler (reduce LR when validation loss plateaus)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=2
)

scaler = torch.cuda.amp.GradScaler()
# Out:
# /tmp/ipykernel_2509/126794699.py:16: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()

# %% [markdown]
# ## 5a. Train

# %%
train_losses = []
train_accs = []
val_losses = []
val_accs = []

print("Starting training...")
print(f"{'Epoch':<8} {'Train Loss':<12} {'Train Acc':<12} {'Validation Loss':<12} {'Validation Acc':<12}")
print("-" * 60)

for epoch in range(NUM_EPOCHS):
    # Train
    train_loss, train_acc = train_one_epoch(simple_model, train_loader8, criterion, optimizer, device, scaler)

    # Evaluate
    val_loss, val_acc = evaluate(simple_model, val_loader8, criterion, device)

    # Update scheduler
    scheduler.step(val_loss)

    # Save metrics
    train_losses.append(train_loss)
    train_accs.append(train_acc)
    val_losses.append(val_loss)
    val_accs.append(val_acc)

    print(f"{epoch+1:<8} {train_loss:<12.4f} {train_acc:<12.2f} {val_loss:<12.4f} {val_acc:<12.2f}")

print("\nTraining complete!")
# Out:
# Starting training...
# Epoch    Train Loss   Train Acc    Validation Loss Validation Acc
# ------------------------------------------------------------
# /tmp/ipykernel_2509/3757051921.py:16: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# 1        1.4982       24.67        1.4388       24.40
# 2        1.4127       27.59        1.3802       28.00
# 3        1.4014       28.56        1.3806       28.00
# 4        1.3905       26.08        1.4672       29.20
# 5        1.3871       29.09        1.3810       26.40
# 6        1.3749       28.56        1.3915       26.80
# 7        1.3689       29.27        1.3908       26.80
# 8        1.3652       31.83        1.3771       27.20
# 9        1.3657       30.59        1.4060       26.40
# 10       1.3634       31.92        1.3804       25.20
# 11       1.3614       32.63        1.3828       26.40
# 12       1.3482       33.24        1.3890       26.00
# 13       1.3417       33.95        1.3956       28.40
# 14       1.3342       34.57        1.4101       27.20
# 15       1.3386       33.78        1.4063       28.00
# 16       1.3345       35.63        1.3954       27.20
# 17       1.3325       34.84        1.3988       27.20
# 18       1.3272       37.58        1.4015       26.80
# 19       1.3223       37.14        1.4064       27.60
# 20       1.3234       37.31        1.4080       30.40
#
# Training complete!

# %% [markdown]
# ## 5b. Accuracy Loss Plots

# %%
# Plot training curves
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Loss plot
axes[0].plot(train_losses, label='Train Loss', marker='o')
axes[0].plot(val_losses, label='Validation Loss', marker='o')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].set_title('Figure 1a: Basic CNN Grouped Receiver Training and Validation Loss')
axes[0].legend()
axes[0].grid(True)

# Accuracy plot
axes[1].plot(train_accs, label='Train Accuracy', marker='o')
axes[1].plot(val_accs, label='Validation Accuracy', marker='o')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy (%)')
axes[1].set_title('Figure 1b: Basic CNN Grouped Receiver Training and Validation Accuracy')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5c. Confusion Matrix

# %%
classes = val_loader8.dataset.classes

# %%
plt.figure(figsize=(6, 5))
cm = plot_confusion_matrix(simple_model, val_loader8, device, classes)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=classes,
            yticklabels=classes)
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.title('Figure 2: Grouped Receiver Confusion Matrix')
plt.show()

# %% [markdown]
# 30.40% accuracy and overpredicts outside1, but fair variablility in predictions with no 0 entries of confusion matrix.

# %% [markdown]
# #6. Run VGG

# %% [markdown]
# Configuration

# %%
# Training configuration
NUM_EPOCHS = 20
LEARNING_RATE = 0.0001

# Loss function
criterion = nn.CrossEntropyLoss()

# Optimizer
optimizer = optim.Adam(vgg_model.parameters(), lr=LEARNING_RATE)

# Learning rate scheduler (reduce LR when validation loss plateaus)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=2
)

scaler = torch.cuda.amp.GradScaler()
# Out:
# /tmp/ipykernel_2509/3417175722.py:16: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()

# %% [markdown]
# ##6a. Train

# %%
train_losses = []
train_accs = []
val_losses = []
val_accs = []

print("Starting training...")
print(f"{'Epoch':<8} {'Train Loss':<12} {'Train Acc':<12} {'Val Loss':<12} {'Val Acc':<12}")
print("-" * 60)

for epoch in range(NUM_EPOCHS):
    # Train
    train_loss, train_acc = train_one_epoch(vgg_model, train_loader8, criterion, optimizer, device, scaler)

    # Evaluate
    val_loss, val_acc = evaluate(vgg_model, val_loader8, criterion, device)

    # Update scheduler
    scheduler.step(val_loss)

    # Save metrics
    train_losses.append(train_loss)
    train_accs.append(train_acc)
    val_losses.append(val_loss)
    val_accs.append(val_acc)

    print(f"{epoch+1:<8} {train_loss:<12.4f} {train_acc:<12.2f} {val_loss:<12.4f} {val_acc:<12.2f}")

print("\nTraining complete!")
# Out:
# Starting training...
# Epoch    Train Loss   Train Acc    Val Loss     Val Acc
# ------------------------------------------------------------
# /tmp/ipykernel_2509/3757051921.py:16: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# 1        1.5160       25.55        1.4171       29.20
# 2        1.4117       27.94        1.3955       27.60
# 3        1.3931       26.17        1.4029       27.20
# 4        1.3888       29.00        1.3807       27.60
# 5        1.3886       27.85        1.3815       27.60
# 6        1.3887       26.61        1.3867       28.00
# 7        1.3836       29.89        1.3820       24.80
# 8        1.3761       28.38        1.3856       27.60
# 9        1.3766       27.50        1.3819       28.40
# 10       1.3742       28.29        1.3826       26.40
# 11       1.3727       29.27        1.3817       26.00
# 12       1.3670       29.27        1.3818       28.40
# 13       1.3712       28.47        1.3821       24.80
# 14       1.3672       28.91        1.3784       25.60
# 15       1.3624       29.00        1.3745       28.80
# 16       1.3623       29.89        1.3776       26.40
# 17       1.3676       29.62        1.3777       25.60
# 18       1.3567       32.10        1.3777       29.20
# 19       1.3623       30.33        1.3765       27.20
# 20       1.3640       30.42        1.3793       26.00
#
# Training complete!

# %% [markdown]
# ## 6b. Accuracy and Loss Plots

# %%
# Plot training curves
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Loss plot
axes[0].plot(train_losses, label='Train Loss', marker='o')
axes[0].plot(val_losses, label='Validation Loss', marker='o')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].set_title('Figure 3a: VGG Grouped Receiver Training and Validation Loss')
axes[0].legend()
axes[0].grid(True)

# Accuracy plot
axes[1].plot(train_accs, label='Validation Accuracy', marker='o')
axes[1].plot(val_accs, label='Validation Accuracy', marker='o')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy (%)')
axes[1].set_title('Figure 3b: VGG Grouped Receiver Training and Validation Accuracy')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6c. Confusion Matrix

# %%
classes = val_loader8.dataset.classes

# %%
plt.figure(figsize=(6, 5))
cm = plot_confusion_matrix(vgg_model, val_loader8, device, classes)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=classes,
            yticklabels=classes)
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.title('Figure 4: VGG Grouped Receiver Confusion Matrix')
plt.show()

# %% [markdown]
# Similar results, 26% accuracy, but the vgg model cannot predict outside2 and over predicts nonpin hitters.  The simple model has better variation, so I retain the simple cnn with better performance.

# %% [markdown]
# # 7. Test Performance

# %%
classes = test_loader8.dataset.classes
plt.figure(figsize=(6, 5))
cm = plot_confusion_matrix(simple_model, test_loader8, device, classes)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=classes,
            yticklabels=classes)
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.title('Figure 5: Simple CNN Receiver Confusion Matrix on Test Set')
plt.show()

# %%
(7+13+61+2)/len(test_ds)
# Out:
# 0.28040540540540543

# %% [markdown]
# 28.04% accuracy on the test set which is barely better than guessing, but fair prediction variation.  Usually within the predicted class it pedicts the true class the most.
